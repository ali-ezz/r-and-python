# %% [markdown]
# # Complete Guide to Pandas.

# %% [markdown]
# ## Table of Contents(ToC):
#
# #### 1. [The Basics](#content1)
#
# #### 2. [Creating DataFrame](#content2)
#
# #### 3. [Treating null values](#content3)
#
# #### 4. [Modify/Add new column(s).](#content4)
#
# #### 5. [Deleting columns](#content5)
#
# #### 6. [Renaming columns](#content6)
#
# #### 7.i. [Slicing DataFrame](#content7)
#
# #### 7.ii. [Slicing using iloc and loc](#content8)
#
# #### 8. [Adding a row](#content9)
#
# #### 9. [Dropping row(s)](#content10)
#
# #### 10. [Sorting](#content11)
#
# #### 11. [Joins](#content12)
#
# #### 12. [Groupby](#content13)

# %% [markdown]
# #### Importing modules.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# #### Importing data.
#
# For this tutorial, we will use the standard Titanic Dataset.

# %%
train=pd.read_csv('train.csv')
df=train.copy()

# %% [markdown]
# <a id="content1"></a>
# ## 1. The Basics

# %%
# See the first 5 rows
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# last 5 rows.
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# n_samples x n_features
df.shape
# Out:
# (891, 12)

# %%
#List of all the columns
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Rows index
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
# Values with their counts in a particular column
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
# General description of dataset.
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# <a id="content2"></a>
# ## 2. Creating DataFrame

# %%
# empty data frame
df_empty=pd.DataFrame()
df_empty.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# **With INDEX**

# %%
# From dict
student_dict={'Name':['A','B','C'],'Age':[24,18,17],'Roll':[1,2,3]}
df_student=pd.DataFrame(student_dict).reset_index(drop=False) # without this adds an additional index column in df
df_student.head()
# Out:
#    index Name  Age  Roll
# 0      0    A   24     1
# 1      1    B   18     2
# 2      2    C   17     3

# %% [markdown]
# **Without INDEX**

# %%
# From dict
student_dict={'Name':['A','B','C'],'Age':[24,18,17],'Roll':[1,2,3]}
df_student=pd.DataFrame(student_dict).reset_index(drop=True) # without this adds an additional index column in df
df_student.head()
# Out:
#   Name  Age  Roll
# 0    A   24     1
# 1    B   18     2
# 2    C   17     3

# %% [markdown]
# <a id="content3"></a>
# ## 3. Treating null values

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# on whole df.
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# on a particular column
df['Age'].isnull().sum()
# Out:
# 177

# %% [markdown]
# #### Impute null values

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
print(df['Age'].isnull().sum())
# Out:
# 0

# %% [markdown]
# <a id="content4"></a>
# ## 4. Modify/Add new column(s).
# Adding another column or modify a column.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['gender']=df['Sex'].map({"male":'0',"female":"1"})
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked gender
# 0      0         A/5 21171   7.2500   NaN        S      0
# 1      0          PC 17599  71.2833   C85        C      1
# 2      0  STON/O2. 3101282   7.9250   NaN        S      1
# 3      0            113803  53.1000  C123        S      1
# 4      0            373450   8.0500   NaN        S      0

# %%
string = 'ahmed,mostafa'
string.split(",")
# Out:
# ['ahmed', 'mostafa']

# %%
def add(a,b):
    return a+b

add=lambda a,b: a+b
add(1,2)

# %%
# Finding last name and first name from Name column.
df['last_name']=df['Name'].apply(lambda x: x.split(',')[0])
df['first_name']=df['Name'].apply(lambda x: ' '.join(x.split(',')[1:]))

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked gender  last_name  \
# 0      0         A/5 21171   7.2500   NaN        S      0     Braund
# 1      0          PC 17599  71.2833   C85        C      1    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S      1  Heikkinen
# 3      0            113803  53.1000  C123        S      1   Futrelle
# 4      0            373450   8.0500   NaN        S      0      Allen
#
#                                     first_name
# 0                              Mr. Owen Harris
# 1   Mrs. John Bradley (Florence Briggs Thayer)
# 2                                  Miss. Laina
# 3           Mrs. Jacques Heath (Lily May Peel)
# 4                            Mr. William Henry

# %%
# Sets to 1 for men in 3rd class.
df['Third&Men']=df.apply(lambda row: int(row['Pclass']==3 and row['gender']=="0"),axis=1)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked gender  last_name  \
# 0      0         A/5 21171   7.2500   NaN        S      0     Braund
# 1      0          PC 17599  71.2833   C85        C      1    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S      1  Heikkinen
# 3      0            113803  53.1000  C123        S      1   Futrelle
# 4      0            373450   8.0500   NaN        S      0      Allen
#
#                                     first_name  Third&Men
# 0                              Mr. Owen Harris          1
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0
# 2                                  Miss. Laina          0
# 3           Mrs. Jacques Heath (Lily May Peel)          0
# 4                            Mr. William Henry          1

# %% [markdown]
# ##### Calling some custom function.

# %%
def findAgeGroup(age):
    if age<18:
        return 1
    elif age>=18 and age<40:
        return 2
    elif age>=40 and age<60:
        return 3
    else:
        return 4
df['Age_group']=df['Age'].apply(lambda x: findAgeGroup(x))
# Calling a custom function.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked gender  last_name  \
# 0      0         A/5 21171   7.2500   NaN        S      0     Braund
# 1      0          PC 17599  71.2833   C85        C      1    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S      1  Heikkinen
# 3      0            113803  53.1000  C123        S      1   Futrelle
# 4      0            373450   8.0500   NaN        S      0      Allen
#
#                                     first_name  Third&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %% [markdown]
# <a id="content5"></a>
# ## 5. Deleting columns

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked gender  last_name  \
# 0      0         A/5 21171   7.2500   NaN        S      0     Braund
# 1      0          PC 17599  71.2833   C85        C      1    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S      1  Heikkinen
# 3      0            113803  53.1000  C123        S      1   Futrelle
# 4      0            373450   8.0500   NaN        S      0      Allen
#
#                                     first_name  Third&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %%
df = df.drop(['PassengerId'],axis=1)
#df=df.drop(['PassengerId'],axis=1,inplace=True)
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#   gender  last_name                                   first_name  Third&Men  \
# 0      0     Braund                              Mr. Owen Harris          1
# 1      1    Cumings   Mrs. John Bradley (Florence Briggs Thayer)          0
# 2      1  Heikkinen                                  Miss. Laina          0
# 3      1   Futrelle           Mrs. Jacques Heath (Lily May Peel)          0
# 4      0      Allen                            Mr. William Henry          1
#
#    Age_group
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2

# %% [markdown]
# <a id="content6"></a>
# ## 6. Renaming columns

# %%
# Lets try to rename some columns.
df=df.rename(columns={'Survived':'survived','Name':'Full Name','last_name':'Surname','first_name':'Name'})
df.head()
# Out:
#    survived  Pclass                                          Full Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#   gender    Surname                                         Name  Third&Men  \
# 0      0     Braund                              Mr. Owen Harris          1
# 1      1    Cumings   Mrs. John Bradley (Florence Briggs Thayer)          0
# 2      1  Heikkinen                                  Miss. Laina          0
# 3      1   Futrelle           Mrs. Jacques Heath (Lily May Peel)          0
# 4      0      Allen                            Mr. William Henry          1
#
#    Age_group
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2

# %% [markdown]
# Similarly, we can do for whichever column we want.

# %% [markdown]
# <a id="content7"></a>
# ## 7.i Slicing DataFrame

# %%
df.head()
# Out:
#    survived  Pclass                                          Full Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#   gender    Surname                                         Name  Third&Men  \
# 0      0     Braund                              Mr. Owen Harris          1
# 1      1    Cumings   Mrs. John Bradley (Florence Briggs Thayer)          0
# 2      1  Heikkinen                                  Miss. Laina          0
# 3      1   Futrelle           Mrs. Jacques Heath (Lily May Peel)          0
# 4      0      Allen                            Mr. William Henry          1
#
#    Age_group
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2

# %%
df[df['survived'] == 1]
# Out:
#      survived  Pclass                                          Full Name  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 8           1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           1       2                Nasser, Mrs. Nicholas (Adele Achem)
# ..        ...     ...                                                ...
# 875         1       3                   Najib, Miss. Adele Kiamie "Jane"
# 879         1       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880         1       2       Shelley, Mrs. William (Imanita Parrish Hall)
# 887         1       1                       Graham, Miss. Margaret Edith
# 889         1       1                              Behr, Mr. Karl Howell
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 8    female  27.0      0      2            347742  11.1333   NaN        S
# 9    female  14.0      1      0            237736  30.0708   NaN        C
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 875  female  15.0      0      0              2667   7.2250   NaN        C
# 879  female  56.0      0      1             11767  83.1583   C50        C
# 880  female  25.0      0      1            230433  26.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
#
#     gender    Surname                                         Name  Third&Men  \
# 1        1    Cumings   Mrs. John Bradley (Florence Briggs Thayer)          0
# 2        1  Heikkinen                                  Miss. Laina          0
# 3        1   Futrelle           Mrs. Jacques Heath (Lily May Peel)          0
# 8        1    Johnson     Mrs. Oscar W (Elisabeth Vilhelmina Berg)          0
# 9        1     Nasser                  Mrs. Nicholas (Adele Achem)          0
# ..     ...        ...                                          ...        ...
# 875      1      Najib                    Miss. Adele Kiamie "Jane"          0
# 879      1     Potter        Mrs. Thomas Jr (Lily Alexenia Wilson)          0
# 880      1    Shelley          Mrs. William (Imanita Parrish Hall)          0
# 887      1     Graham                         Miss. Margaret Edith          0
# 889      0       Behr                              Mr. Karl Howell          0
#
#      Age_group
# 1            2
# 2            2
# 3            2
# 8            2
# 9            1
# ..         ...
# 875          1
# 879          3
# 880          2
# 887          2
# 889          2
#
# [342 rows x 16 columns]

# %%
# All rows with pclass==3
df_third_class=df[df['Pclass']==3]
df_third_class.head()
# Out:
#    survived  Pclass                       Full Name     Sex        Age  SibSp  \
# 0         0       3         Braund, Mr. Owen Harris    male  22.000000      1
# 2         1       3          Heikkinen, Miss. Laina  female  26.000000      0
# 4         0       3        Allen, Mr. William Henry    male  35.000000      0
# 5         0       3                Moran, Mr. James    male  29.699118      0
# 7         0       3  Palsson, Master. Gosta Leonard    male   2.000000      3
#
#    Parch            Ticket     Fare Cabin Embarked gender    Surname  \
# 0      0         A/5 21171   7.2500   NaN        S      0     Braund
# 2      0  STON/O2. 3101282   7.9250   NaN        S      1  Heikkinen
# 4      0            373450   8.0500   NaN        S      0      Allen
# 5      0            330877   8.4583   NaN        Q      0      Moran
# 7      1            349909  21.0750   NaN        S      0    Palsson
#
#                      Name  Third&Men  Age_group
# 0         Mr. Owen Harris          1          2
# 2             Miss. Laina          0          2
# 4       Mr. William Henry          1          2
# 5               Mr. James          1          2
# 7   Master. Gosta Leonard          1          1

# %%
# Females with age > 60
df_aged=df[(df['Age']>60) & (df['gender']=="1")]
df_aged.head()
# Out:
#      survived  Pclass                                  Full Name     Sex  \
# 275         1       1          Andrews, Miss. Kornelia Theodosia  female
# 483         1       3                     Turkula, Mrs. (Hedwig)  female
# 829         1       1  Stone, Mrs. George Nelson (Martha Evelyn)  female
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked gender  Surname  \
# 275  63.0      1      0   13502  77.9583    D7        S      1  Andrews
# 483  63.0      0      0    4134   9.5875   NaN        S      1  Turkula
# 829  62.0      0      0  113572  80.0000   B28      NaN      1    Stone
#
#                                     Name  Third&Men  Age_group
# 275             Miss. Kornelia Theodosia          0          4
# 483                        Mrs. (Hedwig)          0          4
# 829   Mrs. George Nelson (Martha Evelyn)          0          4

# %% [markdown]
# **Note that all these three ladies were saved as they were senior citizen and women so they may have been given priority.**

# %%
# Selecting some columns.
df1=df[['Age','Pclass','gender']]
df1.head()
# Out:
#     Age  Pclass gender
# 0  22.0       3      0
# 1  38.0       1      1
# 2  26.0       3      1
# 3  35.0       1      1
# 4  35.0       3      0

# %%
x= 1,2
type(x)
# Out:
# tuple

# %%
# Select numerical columns only
#numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

df_num = df.select_dtypes(include='number')
df_num.head()
# Out:
#    survived  Pclass   Age  SibSp  Parch     Fare  Third&Men  Age_group
# 0         0       3  22.0      1      0   7.2500          1          2
# 1         1       1  38.0      1      0  71.2833          0          2
# 2         1       3  26.0      0      0   7.9250          0          2
# 3         1       1  35.0      1      0  53.1000          0          2
# 4         0       3  35.0      0      0   8.0500          1          2

# %%
# categorical columns
df_cat=df.select_dtypes(include=['object'])
df_cat.head()
# Out:
#                                            Full Name     Sex  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked gender    Surname  \
# 0         A/5 21171   NaN        S      0     Braund
# 1          PC 17599   C85        C      1    Cumings
# 2  STON/O2. 3101282   NaN        S      1  Heikkinen
# 3            113803  C123        S      1   Futrelle
# 4            373450   NaN        S      0      Allen
#
#                                           Name
# 0                              Mr. Owen Harris
# 1   Mrs. John Bradley (Florence Briggs Thayer)
# 2                                  Miss. Laina
# 3           Mrs. Jacques Heath (Lily May Peel)
# 4                            Mr. William Henry

# %% [markdown]
# <a id="content8"></a>
# ## 7.ii Slicing using iloc and loc

# %% [markdown]
# #### iloc

# %%
df.head()
# Out:
#    survived  Pclass                                          Full Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#   gender    Surname                                         Name  Third&Men  \
# 0      0     Braund                              Mr. Owen Harris          1
# 1      1    Cumings   Mrs. John Bradley (Florence Briggs Thayer)          0
# 2      1  Heikkinen                                  Miss. Laina          0
# 3      1   Futrelle           Mrs. Jacques Heath (Lily May Peel)          0
# 4      0      Allen                            Mr. William Henry          1
#
#    Age_group
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2

# %%
# First 100 rows & all columns
df_sub1=df.iloc[0:100,:]
df_sub1
# Out:
#     survived  Pclass                                          Full Name  \
# 0          0       3                            Braund, Mr. Owen Harris
# 1          1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1       3                             Heikkinen, Miss. Laina
# 3          1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0       3                           Allen, Mr. William Henry
# ..       ...     ...                                                ...
# 95         0       3                        Shorney, Mr. Charles Joseph
# 96         0       1                          Goldschmidt, Mr. George B
# 97         1       1                    Greenfield, Mr. William Bertram
# 98         1       2               Doling, Mrs. John T (Ada Julia Bone)
# 99         0       2                                  Kantor, Mr. Sinai
#
#        Sex        Age  SibSp  Parch            Ticket     Fare    Cabin  \
# 0     male  22.000000      1      0         A/5 21171   7.2500      NaN
# 1   female  38.000000      1      0          PC 17599  71.2833      C85
# 2   female  26.000000      0      0  STON/O2. 3101282   7.9250      NaN
# 3   female  35.000000      1      0            113803  53.1000     C123
# 4     male  35.000000      0      0            373450   8.0500      NaN
# ..     ...        ...    ...    ...               ...      ...      ...
# 95    male  29.699118      0      0            374910   8.0500      NaN
# 96    male  71.000000      0      0          PC 17754  34.6542       A5
# 97    male  23.000000      0      1          PC 17759  63.3583  D10 D12
# 98  female  34.000000      0      1            231919  23.0000      NaN
# 99    male  34.000000      1      0            244367  26.0000      NaN
#
#    Embarked gender      Surname                                         Name  \
# 0         S      0       Braund                              Mr. Owen Harris
# 1         C      1      Cumings   Mrs. John Bradley (Florence Briggs Thayer)
# 2         S      1    Heikkinen                                  Miss. Laina
# 3         S      1     Futrelle           Mrs. Jacques Heath (Lily May Peel)
# 4         S      0        Allen                            Mr. William Henry
# ..      ...    ...          ...                                          ...
# 95        S      0      Shorney                           Mr. Charles Joseph
# 96        C      0  Goldschmidt                                 Mr. George B
# 97        C      0   Greenfield                          Mr. William Bertram
# 98        S      1       Doling                 Mrs. John T (Ada Julia Bone)
# 99        S      0       Kantor                                    Mr. Sinai
#
#     Third&Men  Age_group
# 0           1          2
# 1           0          2
# 2           0          2
# 3           0          2
# 4           1          2
# ..        ...        ...
# 95          1          2
# 96          0          4
# 97          0          2
# 98          0          2
# 99          0          2
#
# [100 rows x 16 columns]

# %%
#First 250 rows with a subset of columns

#df_sub2=df.iloc[:250,['Age']]
# This will throw an error as iloc only consumes integres as indices.

df_sub2=df.iloc[:250,[1,8]]
#Returns first 250 rows and columns at those indices in df.columns.
df_sub2.head()
# Out:
#    Pclass     Fare
# 0       3   7.2500
# 1       1  71.2833
# 2       3   7.9250
# 3       1  53.1000
# 4       3   8.0500

# %% [markdown]
# #### loc

# %%
df.head()
# Out:
#    survived  Pclass                                          Full Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#   gender    Surname                                         Name  Third&Men  \
# 0      0     Braund                              Mr. Owen Harris          1
# 1      1    Cumings   Mrs. John Bradley (Florence Briggs Thayer)          0
# 2      1  Heikkinen                                  Miss. Laina          0
# 3      1   Futrelle           Mrs. Jacques Heath (Lily May Peel)          0
# 4      0      Allen                            Mr. William Henry          1
#
#    Age_group
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2

# %%
# First 500 rows.
df_sub3=df.loc[:500,:]
df_sub3
# Out:
#      survived  Pclass                                          Full Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 496         1       1                     Eustis, Miss. Elizabeth Mussey
# 497         0       3                    Shellard, Mr. Frederick William
# 498         0       1    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 499         0       3                                 Svensson, Mr. Olof
# 500         0       3                                   Calic, Mr. Petar
#
#         Sex        Age  SibSp  Parch            Ticket      Fare    Cabin  \
# 0      male  22.000000      1      0         A/5 21171    7.2500      NaN
# 1    female  38.000000      1      0          PC 17599   71.2833      C85
# 2    female  26.000000      0      0  STON/O2. 3101282    7.9250      NaN
# 3    female  35.000000      1      0            113803   53.1000     C123
# 4      male  35.000000      0      0            373450    8.0500      NaN
# ..      ...        ...    ...    ...               ...       ...      ...
# 496  female  54.000000      1      0             36947   78.2667      D20
# 497    male  29.699118      0      0         C.A. 6212   15.1000      NaN
# 498  female  25.000000      1      2            113781  151.5500  C22 C26
# 499    male  24.000000      0      0            350035    7.7958      NaN
# 500    male  17.000000      0      0            315086    8.6625      NaN
#
#     Embarked gender    Surname                                         Name  \
# 0          S      0     Braund                              Mr. Owen Harris
# 1          C      1    Cumings   Mrs. John Bradley (Florence Briggs Thayer)
# 2          S      1  Heikkinen                                  Miss. Laina
# 3          S      1   Futrelle           Mrs. Jacques Heath (Lily May Peel)
# 4          S      0      Allen                            Mr. William Henry
# ..       ...    ...        ...                                          ...
# 496        C      1     Eustis                       Miss. Elizabeth Mussey
# 497        S      0   Shellard                        Mr. Frederick William
# 498        S      1    Allison       Mrs. Hudson J C (Bessie Waldo Daniels)
# 499        S      0   Svensson                                     Mr. Olof
# 500        S      0      Calic                                    Mr. Petar
#
#      Third&Men  Age_group
# 0            1          2
# 1            0          2
# 2            0          2
# 3            0          2
# 4            1          2
# ..         ...        ...
# 496          0          3
# 497          1          2
# 498          0          2
# 499          1          2
# 500          1          1
#
# [501 rows x 16 columns]

# %%
# Gender and age of age >50
df_sub4=df.loc[(df['Age']>50),['gender','Age']]
df_sub4.head()
# Out:
#    gender   Age
# 6       0  54.0
# 11      1  58.0
# 15      1  55.0
# 33      0  66.0
# 54      0  65.0

# %% [markdown]
# <a id="content9"></a>
# ## 8. Adding a row

# %%
df.head()
# Out:
#    survived  Pclass                                          Full Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#   gender    Surname                                         Name  Third&Men  \
# 0      0     Braund                              Mr. Owen Harris          1
# 1      1    Cumings   Mrs. John Bradley (Florence Briggs Thayer)          0
# 2      1  Heikkinen                                  Miss. Laina          0
# 3      1   Futrelle           Mrs. Jacques Heath (Lily May Peel)          0
# 4      0      Allen                            Mr. William Henry          1
#
#    Age_group
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2

# %%
len(df)

# %%
df.tail()
# Out:
#      survived  Pclass                                 Full Name     Sex  \
# 886         0       2                     Montvila, Rev. Juozas    male
# 887         1       1              Graham, Miss. Margaret Edith  female
# 888         0       3  Johnston, Miss. Catherine Helen "Carrie"  female
# 889         1       1                     Behr, Mr. Karl Howell    male
# 890         0       3                       Dooley, Mr. Patrick    male
#
#            Age  SibSp  Parch      Ticket   Fare Cabin Embarked gender  \
# 886  27.000000      0      0      211536  13.00   NaN        S      0
# 887  19.000000      0      0      112053  30.00   B42        S      1
# 888  29.699118      1      2  W./C. 6607  23.45   NaN        S      1
# 889  26.000000      0      0      111369  30.00  C148        C      0
# 890  32.000000      0      0      370376   7.75   NaN        Q      0
#
#       Surname                             Name  Third&Men  Age_group
# 886  Montvila                      Rev. Juozas          0          2
# 887    Graham             Miss. Margaret Edith          0          2
# 888  Johnston   Miss. Catherine Helen "Carrie"          0          2
# 889      Behr                  Mr. Karl Howell          0          2
# 890    Dooley                      Mr. Patrick          1          2

# %%
len(df)
# Out:
# 892

# %%
# Adding new row using loc
row = {'Survived':1,'Pclass':np.nan,'Full Name':'Peter','Gender':np.nan,'Age':np.nan,'SibSp':np.nan,'Parch':np.nan,'Ticket':np.nan,'Fare':np.nan,'Cabin':np.nan,'Embarke':np.nan}
df.loc[len(df)]=row
df.tail()
# Out:
#      survived  Pclass                                 Full Name     Sex  \
# 888       0.0     3.0  Johnston, Miss. Catherine Helen "Carrie"  female
# 889       1.0     1.0                     Behr, Mr. Karl Howell    male
# 890       0.0     3.0                       Dooley, Mr. Patrick    male
# 891       NaN     NaN                                     Peter     NaN
# 892       NaN     NaN                                     Peter     NaN
#
#            Age  SibSp  Parch      Ticket   Fare Cabin Embarked gender  \
# 888  29.699118    1.0    2.0  W./C. 6607  23.45   NaN        S      1
# 889  26.000000    0.0    0.0      111369  30.00  C148        C      0
# 890  32.000000    0.0    0.0      370376   7.75   NaN        Q      0
# 891        NaN    NaN    NaN         NaN    NaN   NaN      NaN    NaN
# 892        NaN    NaN    NaN         NaN    NaN   NaN      NaN    NaN
#
#       Surname                             Name  Third&Men  Age_group
# 888  Johnston   Miss. Catherine Helen "Carrie"        0.0        2.0
# 889      Behr                  Mr. Karl Howell        0.0        2.0
# 890    Dooley                      Mr. Patrick        1.0        2.0
# 891       NaN                              NaN        NaN        NaN
# 892       NaN                              NaN        NaN        NaN

# %%
li = [1,2,3]
li[3]=4
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[56], line 2
#       1 li = [1,2,3]
# ----> 2 li[3]=4
#
# IndexError: list assignment index out of range

# %% [markdown]
# <a id="content10"></a>
# ## 9. Dropping row(s)

# %%
df=df.drop(df.index[-1],axis=0) # Deletes last row
df.tail()
# Out:
#      survived  Pclass                                 Full Name     Sex  \
# 886       0.0     2.0                     Montvila, Rev. Juozas    male
# 887       1.0     1.0              Graham, Miss. Margaret Edith  female
# 888       0.0     3.0  Johnston, Miss. Catherine Helen "Carrie"  female
# 889       1.0     1.0                     Behr, Mr. Karl Howell    male
# 890       0.0     3.0                       Dooley, Mr. Patrick    male
#
#            Age  SibSp  Parch      Ticket   Fare Cabin Embarked gender  \
# 886  27.000000    0.0    0.0      211536  13.00   NaN        S      0
# 887  19.000000    0.0    0.0      112053  30.00   B42        S      1
# 888  29.699118    1.0    2.0  W./C. 6607  23.45   NaN        S      1
# 889  26.000000    0.0    0.0      111369  30.00  C148        C      0
# 890  32.000000    0.0    0.0      370376   7.75   NaN        Q      0
#
#       Surname                             Name  Third&Men  Age_group
# 886  Montvila                      Rev. Juozas        0.0        2.0
# 887    Graham             Miss. Margaret Edith        0.0        2.0
# 888  Johnston   Miss. Catherine Helen "Carrie"        0.0        2.0
# 889      Behr                  Mr. Karl Howell        0.0        2.0
# 890    Dooley                      Mr. Patrick        1.0        2.0

# %% [markdown]
# <a id="content11"></a>
# ## 10. Sorting

# %%
df.head()
# Out:
#    survived  Pclass                                          Full Name  \
# 0       0.0     3.0                            Braund, Mr. Owen Harris
# 1       1.0     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       1.0     3.0                             Heikkinen, Miss. Laina
# 3       1.0     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       0.0     3.0                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0    1.0    0.0         A/5 21171   7.2500   NaN        S
# 1  female  38.0    1.0    0.0          PC 17599  71.2833   C85        C
# 2  female  26.0    0.0    0.0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0    1.0    0.0            113803  53.1000  C123        S
# 4    male  35.0    0.0    0.0            373450   8.0500   NaN        S
#
#   gender    Surname                                         Name  Third&Men  \
# 0      0     Braund                              Mr. Owen Harris        1.0
# 1      1    Cumings   Mrs. John Bradley (Florence Briggs Thayer)        0.0
# 2      1  Heikkinen                                  Miss. Laina        0.0
# 3      1   Futrelle           Mrs. Jacques Heath (Lily May Peel)        0.0
# 4      0      Allen                            Mr. William Henry        1.0
#
#    Age_group
# 0        2.0
# 1        2.0
# 2        2.0
# 3        2.0
# 4        2.0

# %%
# sorting by age say in decreasing order.
df=df.sort_values(by=['Age',"Pclass"],ascending=False) # can specify multiple columns in a list as well.
df.head()
# Out:
#      survived  Pclass                             Full Name   Sex   Age  \
# 630       1.0     1.0  Barkworth, Mr. Algernon Henry Wilson  male  80.0
# 851       0.0     3.0                   Svensson, Mr. Johan  male  74.0
# 96        0.0     1.0             Goldschmidt, Mr. George B  male  71.0
# 493       0.0     1.0               Artagaveytia, Mr. Ramon  male  71.0
# 116       0.0     3.0                  Connors, Mr. Patrick  male  70.5
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked gender       Surname  \
# 630    0.0    0.0     27042  30.0000   A23        S      0     Barkworth
# 851    0.0    0.0    347060   7.7750   NaN        S      0      Svensson
# 96     0.0    0.0  PC 17754  34.6542    A5        C      0   Goldschmidt
# 493    0.0    0.0  PC 17609  49.5042   NaN        C      0  Artagaveytia
# 116    0.0    0.0    370369   7.7500   NaN        Q      0       Connors
#
#                            Name  Third&Men  Age_group
# 630   Mr. Algernon Henry Wilson        0.0        4.0
# 851                   Mr. Johan        1.0        4.0
# 96                 Mr. George B        0.0        4.0
# 493                   Mr. Ramon        0.0        4.0
# 116                 Mr. Patrick        1.0        4.0

# %% [markdown]
# <a id="content12"></a>
# ## 11. Joins

# %% [markdown]
# Let's create two separate data frames and try all 5 (Cross,Inner, Left, Right,and Outer Joins).

# %%
sno=[i+1 for i in range(100)]
marks=np.random.randint(100,size=100)
print(len(marks))
marks_df=pd.DataFrame({'Sno':sno,'Marks':marks})
marks_df.head()
# Out:
# 100
#    Sno  Marks
# 0    1     17
# 1    2     81
# 2    3     85
# 3    4     37
# 4    5     92

# %%
sno=[i+1 for i in range(100)]
age=np.random.randint(100,size=100)
print(len(marks))
age_df=pd.DataFrame({'Sno':sno,'Age':age})
age_df.head()
# Out:
# 100
#    Sno  Age
# 0    1   71
# 1    2   27
# 2    3   54
# 3    4   29
# 4    5   57

# %% [markdown]
# #### Cross join

# %%
cross_join=pd.merge(marks_df,age_df,how='cross')
print(cross_join.shape)
cross_join.head()
# Out:
# (10000, 4)
#    Sno_x  Marks  Sno_y  Age
# 0      1     17      1   71
# 1      1     17      2   27
# 2      1     17      3   54
# 3      1     17      4   29
# 4      1     17      5   57

# %% [markdown]
# #### Inner Join

# %%
inner_join=pd.merge(age_df,marks_df,how='inner',on='Sno') # 'how' defaults to 'inner' only.
print(inner_join.shape)
inner_join.head()
# Out:
# (100, 3)
#    Sno  Age  Marks
# 0    1   71     17
# 1    2   27     81
# 2    3   54     85
# 3    4   29     37
# 4    5   57     92

# %% [markdown]
# #### Left and Right Outer Join(s)

# %% [markdown]
# Lets add some more rows to either frame so that left and right outer join makes sense

# %%
age_df.loc[len(age_df)]={'Sno':101,'Age':23}
age_df.loc[len(age_df)]={'Sno':102,'Age':27}
age_df.loc[len(age_df)]={'Sno':104,'Age':29}
age_df.loc[len(age_df)]={'Sno':103,'Age':32}
age_df.loc[len(age_df)]={'Sno':105,'Age':53}

# %%
#left join
left_join=pd.merge(age_df,marks_df,how='left',on='Sno')
print(left_join.shape)
left_join
# Out:
# (105, 3)
#      Sno  Age  Marks
# 0      1   71   17.0
# 1      2   27   81.0
# 2      3   54   85.0
# 3      4   29   37.0
# 4      5   57   92.0
# ..   ...  ...    ...
# 100  101   23    NaN
# 101  102   27    NaN
# 102  104   29    NaN
# 103  103   32    NaN
# 104  105   53    NaN
#
# [105 rows x 3 columns]

# %% [markdown]
#  **Marks=Nan** confirms the left join.

# %%
#right join
right_join=pd.merge(marks_df,age_df,how='right',on='Sno')
print(right_join.shape)
right_join.tail()
# Out:
# (105, 3)
#      Sno  Marks  Age
# 100  101    NaN   23
# 101  102    NaN   27
# 102  104    NaN   29
# 103  103    NaN   32
# 104  105    NaN   53

# %% [markdown]
# **Marks=Nan** confirms the right join in this case as the order of input frames is also reversed.

# %% [markdown]
# <a id="content13"></a>
# ## 12. Groupby
#
# Let's get back to our titanic dataset.

# %%
df.head()
# Out:
#      survived  Pclass                             Full Name   Sex   Age  \
# 630       1.0     1.0  Barkworth, Mr. Algernon Henry Wilson  male  80.0
# 851       0.0     3.0                   Svensson, Mr. Johan  male  74.0
# 96        0.0     1.0             Goldschmidt, Mr. George B  male  71.0
# 493       0.0     1.0               Artagaveytia, Mr. Ramon  male  71.0
# 116       0.0     3.0                  Connors, Mr. Patrick  male  70.5
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked gender       Surname  \
# 630    0.0    0.0     27042  30.0000   A23        S      0     Barkworth
# 851    0.0    0.0    347060   7.7750   NaN        S      0      Svensson
# 96     0.0    0.0  PC 17754  34.6542    A5        C      0   Goldschmidt
# 493    0.0    0.0  PC 17609  49.5042   NaN        C      0  Artagaveytia
# 116    0.0    0.0    370369   7.7500   NaN        Q      0       Connors
#
#                            Name  Third&Men  Age_group
# 630   Mr. Algernon Henry Wilson        0.0        4.0
# 851                   Mr. Johan        1.0        4.0
# 96                 Mr. George B        0.0        4.0
# 493                   Mr. Ramon        0.0        4.0
# 116                 Mr. Patrick        1.0        4.0

# %% [markdown]
# #### Before, we move onto Groupby in pandas, lets recollect groupby from SQL. A SQL query, may contain hese parts (some might be optional like having etc...):
#
#
# 1. Table name (**from**)
# 2. Some condition to filter rows (**where clause**)
# 3. Attribute to groupby on (**groupby attributes**)
# 4. Filter rows after groupby (**having clause**)
# 5. Display attributes in the final result. (**select**)
#
#
# ##### Let's now see how to mimic this in Pandas ;)

# %%
df.head()
# Out:
#      survived  Pclass                             Full Name   Sex   Age  \
# 630       1.0     1.0  Barkworth, Mr. Algernon Henry Wilson  male  80.0
# 851       0.0     3.0                   Svensson, Mr. Johan  male  74.0
# 96        0.0     1.0             Goldschmidt, Mr. George B  male  71.0
# 493       0.0     1.0               Artagaveytia, Mr. Ramon  male  71.0
# 116       0.0     3.0                  Connors, Mr. Patrick  male  70.5
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked gender       Surname  \
# 630    0.0    0.0     27042  30.0000   A23        S      0     Barkworth
# 851    0.0    0.0    347060   7.7750   NaN        S      0      Svensson
# 96     0.0    0.0  PC 17754  34.6542    A5        C      0   Goldschmidt
# 493    0.0    0.0  PC 17609  49.5042   NaN        C      0  Artagaveytia
# 116    0.0    0.0    370369   7.7500   NaN        Q      0       Connors
#
#                            Name  Third&Men  Age_group
# 630   Mr. Algernon Henry Wilson        0.0        4.0
# 851                   Mr. Johan        1.0        4.0
# 96                 Mr. George B        0.0        4.0
# 493                   Mr. Ramon        0.0        4.0
# 116                 Mr. Patrick        1.0        4.0

# %%
groups=df.groupby(['Pclass'])
# uncomment this:
# groups.groups
groups.get_group(3) # Give some another no say 2 or 3 for its Pclass.
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_21184\3592587135.py:4: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   groups.get_group(3) # Give some another no say 2 or 3 for its Pclass.
#      survived  Pclass                        Full Name     Sex    Age  SibSp  \
# 851       0.0     3.0              Svensson, Mr. Johan    male  74.00    0.0
# 116       0.0     3.0             Connors, Mr. Patrick    male  70.50    0.0
# 280       0.0     3.0                 Duane, Mr. Frank    male  65.00    0.0
# 483       1.0     3.0           Turkula, Mrs. (Hedwig)  female  63.00    0.0
# 326       0.0     3.0        Nysveen, Mr. Johan Hansen    male  61.00    0.0
# ..        ...     ...                              ...     ...    ...    ...
# 386       0.0     3.0  Goodwin, Master. Sidney Leonard    male   1.00    5.0
# 381       1.0     3.0      Nakid, Miss. Maria ("Mary")  female   1.00    0.0
# 469       1.0     3.0    Baclini, Miss. Helene Barbara  female   0.75    2.0
# 644       1.0     3.0           Baclini, Miss. Eugenie  female   0.75    2.0
# 803       1.0     3.0  Thomas, Master. Assad Alexander    male   0.42    0.0
#
#      Parch   Ticket     Fare Cabin Embarked gender   Surname  \
# 851    0.0   347060   7.7750   NaN        S      0  Svensson
# 116    0.0   370369   7.7500   NaN        Q      0   Connors
# 280    0.0   336439   7.7500   NaN        Q      0     Duane
# 483    0.0     4134   9.5875   NaN        S      1   Turkula
# 326    0.0   345364   6.2375   NaN        S      0   Nysveen
# ..     ...      ...      ...   ...      ...    ...       ...
# 386    2.0  CA 2144  46.9000   NaN        S      0   Goodwin
# 381    2.0     2653  15.7417   NaN        C      1     Nakid
# 469    1.0     2666  19.2583   NaN        C      1   Baclini
# 644    1.0     2666  19.2583   NaN        C      1   Baclini
# 803    1.0     2625   8.5167   NaN        C      0    Thomas
#
#                          Name  Third&Men  Age_group
# 851                 Mr. Johan        1.0        4.0
# 116               Mr. Patrick        1.0        4.0
# 280                 Mr. Frank        1.0        4.0
# 483             Mrs. (Hedwig)        0.0        4.0
# 326          Mr. Johan Hansen        1.0        4.0
# ..                        ...        ...        ...
# 386    Master. Sidney Leonard        1.0        1.0
# 381      Miss. Maria ("Mary")        0.0        1.0
# 469      Miss. Helene Barbara        0.0        1.0
# 644             Miss. Eugenie        0.0        1.0
# 803   Master. Assad Alexander        1.0        1.0
#
# [491 rows x 16 columns]

# %% [markdown]
# #### Average Age per Pclass

# %%
df_grp1=df.groupby(['Pclass'])
#df_grp1.head()

# %%
df.groupby(['Pclass'])['Age'].mean()
# Out:
# Pclass
# 1.0    37.048118
# 2.0    29.866958
# 3.0    26.403259
# Name: Age, dtype: float64

# %%
#Average Age per Pclass
df_grp1['Age'].mean()
# Out:
# Pclass
# 1.0    37.048118
# 2.0    29.866958
# 3.0    26.403259
# Name: Age, dtype: float64

# %%
# Min/Max age per Pclass
df_grp1['Age'].min() #max()
# Out:
# Pclass
# 1.0    0.92
# 2.0    0.67
# 3.0    0.42
# Name: Age, dtype: float64

# %%
# Count
df_grp1['Age'].count()
# Out:
# Pclass
# 1.0    216
# 2.0    184
# 3.0    491
# Name: Age, dtype: int64

# %% [markdown]
# #### Using agg() function.
# We can use the aggregate fucntion to aggregate results based on some column  or our custom condition

# %%
df=train.copy()
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Average per Pclass using 'agg' this time
df_grp2=df.groupby(['Pclass']).agg({'Age':'mean','Fare':'median'})
df_grp2.head()
# Out:
#               Age     Fare
# Pclass
# 1       38.233441  60.2875
# 2       29.877630  14.2500
# 3       25.140620   8.0500

# %%
# Names of all the pasengers in that class.
df_grp4=df.groupby(['Pclass']).agg({'Name':lambda x:', '.join(x)})
df_grp4.head()
# Out:
#                                                      Name
# Pclass
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       Nasser, Mrs. Nicholas (Adele Achem), Hewlett, ...
# 3       Braund, Mr. Owen Harris, Heikkinen, Miss. Lain...

# %% [markdown]
# ## TASK:
# 1️⃣ Convert the dictionary into a pandas DataFrame.
#
# 2️⃣ Display the first 3 rows of the DataFrame.
#
# 3️⃣ Find the average marks of all students.
#
# 4️⃣ Find the maximum marks scored.
#
# 5️⃣ Display the names of students who belong to the CS department.
#
# 6️⃣ Add a new column called Passed:
#
# True if Marks ≥ 80
#
# False otherwise
#
# 7️⃣ Count how many students are in each department.

# %%
data = {
    "Student_ID": [1, 2, 3, 4, 5],
    "Name": ["Ali", "Sara", "Omar", "Mona", "Youssef"],
    "Age": [20, 22, 21, 23, 20],
    "Marks": [85, 90, 78, 92, 88],
    "Department": ["CS", "IT", "CS", "IT", "CS"]
}

# %% [markdown]
# **Solution:**

# %%
import pandas as pd

data = {
    "Student_ID": [1, 2, 3, 4, 5],
    "Name": ["Ali", "Sara", "Omar", "Mona", "Youssef"],
    "Age": [20, 22, 21, 23, 20],
    "Marks": [85, 90, 78, 92, 88],
    "Department": ["CS", "IT", "CS", "IT", "CS"]
}

df = pd.DataFrame(data)
df.head(3)

# %%
average_marks = df['Marks'].mean()
average_marks

# %%
max_marks = df['Marks'].max()
max_marks

# %%
cs_students = df[df['Department'] == 'CS']['Name']
cs_students

# %%
df['Passed'] = df['Marks'] >= 80

# %%
dept_count = df['Department'].value_counts()
dept_count

# %%
df
